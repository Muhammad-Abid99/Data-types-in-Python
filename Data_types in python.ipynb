# %% [markdown]
# # Python Data Types for Beginners
# #### In Python, every piece of data is an object.
#
# #### Understanding Python's built-in data types is fundamental for writing efficient, readable, and bug-free programs.
# #### This notebook will introduce you to Python's core data types and show you best practices on how to work with them.

# %% [markdown]
# ### 1. Numeric Types
#
# #### Python has three main numeric data types:
#
# #### 1. Integer (int) - Whole numbers (e.g., 0, 1, -5, 999).
#
# #### 2. Float (float) -  Numbers with decimal points or in exponential form (e.g., 3.14, 2.7e3).
#
# ### 1.1 Integers
# ### Definition: Integers are whole numbers without a frectional component.
# #### Examples: -10, 0, 42.

# %%
# Example of integers
num1 = 47
num2 = -7
num3 = 0

print("num1:", num1, type(num1))
print("num2:", num2, type(num2))
print("num3:", num3, type(num3))
# Out:
# num1: 47 <class 'int'>
# num2: -7 <class 'int'>
# num3: 0 <class 'int'>

# %% [markdown]
# ## Best Practices:
# #### 1. Use descriptive variable names: Insted of "x" or "y" use "user_age" or "items_count".
# #### 2. Handle potential overflow: In Python 3, integers are of unlimited size (limited by available memory), so you rarely need to worry about overflow.
# #### 3. Avoid ambiguous naming: For example, O (capital letter O) or l (lowercase L) can be confused with numbers.

# %% [markdown]
# ### 1.2 Floats
# ### Definition: Floats represent real numbers that include a fractional component.
# #### Examples: 3.14159, -0.001, 1.5e2 (which equals 150.0)

# %%
# Example of floats
pi = 3.14159
small_float = -0.001
exp_float = 1.5e2 # 150.0 in decimal

print("pi:", pi, type(pi))
print("small_float:", small_float, type(small_float))
print("exp_float:", exp_float, type(exp_float))
# Out:
# pi: 3.14159 <class 'float'>
# small_float: -0.001 <class 'float'>
# exp_float: 150.0 <class 'float'>

# %% [markdown]
# ## Best Practices:
# #### 1. Wathc out for floating-point precision issues. Use decimal or fractions modules if you need precise decimal arithmetic (e.g. currency calculations).
# #### 2. Use underscores for large numbers: Python 3.6+ allows underscores in numeric literals for readability, e.g., 1_000_000.0 instead of 1000000.0.
# #### 3. Check your computations: Floating-point arithmetic can lead to subtle bugs in equality checks. Prefer a tolerance-based approach if comparing floats, for example: pyton Copy

# %% [markdown]
# ### 2. Strings
# #### Definition: A string is a sequence of characters. In Python, strings can be enclosed in single quotes ('...'), double quotes ("..."), or triple quotes ('''...''' or """...""") for multi-line strings.
# #### Examples: "Hello World", 'Python is great!', """Triple quoted strings can span multiple lines""".

# %%
# Examples of strings
greeting = "Hello, Python!"
quote = 'I can use single quotes too.'
multiline_text = """This is a
multi-line string."""

print(greeting, type(greeting))
print(quote, type(quote))
print(multiline_text, type(multiline_text))
# Out:
# Hello, Python! <class 'str'>
# I can use single quotes too. <class 'str'>
# This is a
# multi-line string. <class 'str'>

# %% [markdown]
# ## String Operations

# %%
# Concatenation
first_name = "Muhammad"
last_name = "Abid"
full_name = first_name + " " + last_name # Muhammad Abid

# Repetition
ha_3_times = "Ha" * 3 # HaHaHa

# Indexing and slicing
first_char = greeting[0] # H
substring = greeting[0:5] # Hello

print("Full_name:", full_name)
print("Repetition:", ha_3_times)
print("Firts Char:", first_char)
print("Substring:", substring)
# Out:
# Full_name: Muhammad Abid
# Repetition: HaHaHa
# Firts Char: H
# Substring: Hello

# %% [markdown]
# ## Best Practices:
# #### 1. Use f-strings (formatted strings) for readability (Python 3.6+)

# %%
age = 25
print(f"My age is:",(age))
# Out:
# My age is: 25

# %% [markdown]
# ## 3. Boolean Type
# #### Definition: Booleans are True or False values.
# #### Use: Typically used in condition checks, loops, or logical evaluations.

# %%
is_python_easy = True
likes_coffee = False

print(f"is_python_easy:", type(is_python_easy)) # Usage of f-string
print("likes_coffee:", likes_coffee, type(likes_coffee)) # Without f-string

print(f"value of variable:", is_python_easy, type(is_python_easy))
print("value of variable is:", likes_coffee, type(likes_coffee))
# Out:
# is_python_easy: <class 'bool'>
# likes_coffee: False <class 'bool'>
# value of variable: True <class 'bool'>
# value of variable is: False <class 'bool'>

# %% [markdown]
# ### Best Practices:
# #### 1. Use descriptive names: Insted of flag or status, use is_active or has_errors.
# #### 2. Avoid comparing booleans to True or False directly.
# #### 3. Keep booleans purely boolean: Resist the temptation to mix them with numbers. Although True behaves like 1 and False like 0, it makes the code less clear.

# %%
# Instead of: if is_python_easy == True:
# Do this:
if is_python_easy:
    print("Yes, Python is easy!")
# Out:
# Yes, Python is easy!

# %% [markdown]
# ## 4. NoneType
# #### Definition: None represents the absence of a value.
# #### Use: Often used as a placeholder for optional or missing data.

# %%
nothing_here = None
print(f"nothing here:", type (nothing_here))
# Out:
# nothing here: <class 'NoneType'>

# %% [markdown]
# ### Best Practices:
# #### 1. Check for None with is None rather than == None

# %%
if nothing_here is None:
    print("This variable has no value.")
# Out:
# This variable has no value.

# %% [markdown]
# ## 5. Collections Overview
# #### While primitive data types (like int, float, bool, and str) hold single values, Python's built-in collections let you group multiple items in flexible ways.
# #### The four primary built-in collections are:
#
# #### 1. List - An ordered, mutable sequence.
# #### 2. Tuple - An ordered, immutable sequence.
# #### 3. Dictionary - An unordered set of key-value pairs.
# #### 4. Set - An unordered collection of unique elements.
#
# #### Below, we'll explore each in depth with code examples and best practices.

# %% [markdown]
# ### 5.1 List
# #### Definition & Characteristics
# #### 1. A list is created using square brackets [] or the list () constructor.
# #### 2. It is ordered, meaning elements retain the order in which they're inserted.
# #### 3. It is mutable: You can add, remove, or modify elements after creation.

# %%
# Creating lists in different ways
empty_list = []
numbers = [11, 22, 33, 44, 55]
mixed_list = ["Hello", 77, 3.14, True]

print("Empty list:", empty_list)
print("Numbers list:", numbers)
print("Mixed list:", mixed_list)

# Accessing elements by index
first_num = numbers[0] # 11
last_num = numbers[-1] # 55
last_num1 = numbers[4]
print("First number:", first_num)
print("Last number:", last_num)
print("Last number:", last_num1)
# Out:
# Empty list: []
# Numbers list: [11, 22, 33, 44, 55]
# Mixed list: ['Hello', 77, 3.14, True]
# First number: 11
# Last number: 55
# Last number: 55

# %% [markdown]
# ### Adding, Removing, and Modifying Elements

# %%
# Adding elements
numbers.append(77)         # Adds 77 at the end
numbers.insert(2, 15)      # Inserts 15 at index 2

# Removing elements
removed_item = numbers.pop()   # Removes and returns the last item (77)
numbers.remove(22)             # Removes the first occurrence that is 22

# Modifying an element
numbers[1] = 25                # Changes the element at index 1 to 25

print("Modified numbers list is:", numbers)
print("Removed item:", removed_item)
# Out:
# Modified numbers list is: [11, 25, 33, 44, 55]
# Removed item: 77

# %% [markdown]
# ### 5.2 Tuple
# #### Definition & Characteristics
# #### 1. A tuple is created using parentheses () or the tuple() constructor.
# #### 2. It is ordered, similar to a list.
# #### 3. It is immutable: You cannot add, remove, or change elements once defined. Creation & Basic Operations.

# %%
# Creating tuples
empty_tuple = ()
single_element_tuple = (47,)
numbers_tuple = (10, 20, 30)
mixed_tuple = ("Amjad", 25, True)

print("Empty tuple:", empty_tuple)
print("Single element tuple:", single_element_tuple)
print("Numbers tuple:", numbers_tuple)
print("Mixed tuple:", mixed_tuple)

# Accessing elements by index
first_item = numbers_tuple[0] # 10
print("First item:", first_item)

# Slicing works similarly to lists
sub_tuple = numbers_tuple[1:] # (20, 30)
print("Sliced sub-tuple:", sub_tuple)
# Out:
# Empty tuple: ()
# Single element tuple: (47,)
# Numbers tuple: (10, 20, 30)
# Mixed tuple: ('Amjad', 25, True)
# First item: 10
# Sliced sub-tuple: (20, 30)

# %% [markdown]
# ## Immutability

# %%
# Trying to modify a tuple will raise an error
try:
    numbers_tuple[1] = 99 # This is not allowed
except TypeError as e:
    print("Error:", e)
# Out:
# Error: 'tuple' object does not support item assignment

# %%
# Unpacking a tuple into seperate variables
person_tuple = ("Bob", 30, "Engineer")
name, age, job = person_tuple # Unpack in order

print("Name:", name)
print("Age:", age)
print("Job:", job)
# Out:
# Name: Bob
# Age: 30
# Job: Engineer

# %% [markdown]
# ### Best Practices for Tuples
# #### 1. Use tuple for fixed collections of items that don't change, like coordinates or constant data.
# #### 2. Leverage tuple unpacking to write cleaner code when returning multiple values from a function.
# #### 3. Don't modify: If you need to frequently alter the collection, consider a list.

# %% [markdown]
# ### 5.3 Dictionary
# #### Definition & Characteristics
# #### 1. A dictionary is created using curly braces {} with key-value pairs, or using dict().
# #### 2. It is unordered (though Python 3.7+ maintains order as an implementation detail).
# #### 3. Keys must be unique and immutable (e.g. string, numbers, tuples). Values can be anything.
# #### 4. It is mutable: You can add, remove, or change key-value pairs.
#
# ### Creation & Basic Operations

# %%
# Creating dictionaries
empty_dict = {}
person_dict = {"name": "Ahmed", "age": 30}
another_dict = dict(city="Lahore", country="PK")

print("Empty dict:", empty_dict)
print("Person dict:", person_dict)
print("Another dict:", another_dict)

# Accessing values by key
print("Name:", person_dict["name"])
print("Age:", person_dict.get("age"))    # .get() is safer, returns None if key isn't found
# Out:
# Empty dict: {}
# Person dict: {'name': 'Ahmed', 'age': 30}
# Another dict: {'city': 'Lahore', 'country': 'PK'}
# Name: Ahmed
# Age: 30

# %% [markdown]
# ### Adding, Updating, and Removing Keys

# %%
# Adding or updating a key-value pair
person_dict["city"] = "Karachi" # Adds 'city' if it doesn't else update it

# Removing a key-value pair
removed_value = person_dict.pop("age")  # Removes 'age' and returns its value
print("Removed age:", removed_value)

# Checking if a key exists
if "name" in person_dict:
    print("Name key is present.")

print(person_dict)
# Out:
# Removed age: 30
# Name key is present.
# {'name': 'Ahmed', 'city': 'Karachi'}

# %%
print("Keys:", person_dict.keys())
print("Values:", person_dict.values())
print("Items:", person_dict.items())
# Out:
# Keys: dict_keys(['name', 'city'])
# Values: dict_values(['Ahmed', 'Karachi'])
# Items: dict_items([('name', 'Ahmed'), ('city', 'Karachi')])

# %% [markdown]
# ### Best Practices for Dictionaries
# #### 1. Use dictionaries when you need fast lookups by key.
# #### 2. Keys should be immutable and descriptive (e.g, strings that convey meaning).
# #### 3. Use .get(key, default) to avoid KeyError when a key might not exist.
# #### 4. Dictionaries are great for configuration data, or bundling related data attributes without creating a custom class.

# %% [markdown]
# ### 5.4 Set
# #### Definition & Characteristics
# #### 1. A set is created using curly braces {} or the set() constructor.
# #### 2. It is unordered and does not allow duplicate elements.
# #### 3. It is mutable: You can add or remove elements.
#
# ### Creation & Basic Operations

# %%
# Creating sets
empty_set = set()
numbers_set = {1, 2, 3, 3, 1}  # Duplicates are removed automatically
mixed_set = {"apple", 47, (1, 2)}  # You can store immutable types like tuples

print("Empty set:", empty_set)
print("Numbers set:", numbers_set)
print("Mixed set:", mixed_set)
# Out:
# Empty set: set()
# Numbers set: {1, 2, 3}
# Mixed set: {(1, 2), 47, 'apple'}

# %% [markdown]
# ### Adding and Removing Elements

# %%
numbers_set.add(7)       # Add 7 to the set
numbers_set.discard(2)   # Removes 2 if it exists, no error if it doesn't
# numbers_set.remove(2)  # Removes 2 but raises a KeyError if it doesn't exist

print("Updated set:", numbers_set)
# Out:
# Updated set: {1, 3, 7}

# %% [markdown]
# ### Set Operations
# #### Sets support mathematical set operations like union, intersection, difference, etc

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}

# Union: all elements from both sets
print("Union:", set_a.union(set_b))  # or set_a | set_b

# Intersection: elements common to both
print("Intersection:", set_a.intersection(set_b)) # or set_a & set_b

# Difference: elements in set_a but not in set_b
print("Difference:", set_a.difference(set_b)) # or set_a - set_b

# Symmetric Difference: elements in either set_a or set_b, but not both
print("Symmetric Difference:", set_a.symmetric_difference(set_b)) # or set_a ^ set_b
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 4, 5}

# %% [markdown]
# ### Best Practices for Sets
# #### 1. Use sets when you need to efficiently test for membership (in check) and remove duplicates.
# #### 2. Avoid storing mutable items in a set-items must be hashable (immutable).
# #### 3. Use set operations for cleaner and more efficient code when dealing with membership and overlaps.

# %% [markdown]
# ### 6. Type Conversion (Casting)
# #### You can convert between data types using built-in functions like int(), float(), str(), etc.
